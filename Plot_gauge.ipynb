# %%
### Plot
import pandas as pd
import plotly.graph_objects as go
import matplotlib as plt
import matplotlib.tri as tri
import matplotlib.pyplot as plt
import os
import re

Hi = 18.5

visc = 0.1
b = 0.001
fig, axes = plt.subplots(1,2,figsize = [15,10])

##Shear

def getdf(folder):
    df = pd.read_csv(folder+'/bwave_gauge_700cm.txt', names = ['x','y'], delim_whitespace=True)
    df = df.query('y > -0.02')
    return df



df1=getdf(str(Hi)+'_'+str(0.1)+'/b_'+str(0.0)+'_5')
#df2=getdf(str(Hi)+'_'+str(0.1)+'/b_'+str(0.001)+'_5')
#df3=getdf(str(Hi)+'_'+str(0.1)+'/b_'+str(0.005)+'_5')
df4=getdf(str(Hi)+'_'+str(0.1)+'/b_'+str(0.01)+'_5')
df5=getdf(str(Hi)+'_'+str(0.1)+'/b_'+str(0.02)+'_5')
df6=getdf(str(Hi)+'_'+str(0.1)+'/b_'+str(0.04)+'_5')
df7=getdf(str(Hi)+'_'+str(0.1)+'/b_'+str(0.08)+'_5')

df1a=getdf(str(Hi)+'_'+str(0.01)+'/b_'+str(0.0)+'_5')
df2a=getdf(str(Hi)+'_'+str(0.01)+'/b_'+str(0.001)+'_5')
#df3a=getdf(str(Hi)+'_'+str(0.01)+'/b_'+str(0.005)+'_5')
df4a=getdf(str(Hi)+'_'+str(0.01)+'/b_'+str(0.01)+'_5')
df5a=getdf(str(Hi)+'_'+str(0.01)+'/b_'+str(0.02)+'_5')
df6a=getdf(str(Hi)+'_'+str(0.01)+'/b_'+str(0.04)+'_5')
df7a=getdf(str(Hi)+'_'+str(0.01)+'/b_'+str(0.08)+'_5')





mycolors = ['g','c','b','m']
## c = shear, b = plunge, m = spill

axes[0].set_xlabel("t/T (s)",fontsize = 13)
axes[0].set_ylabel("Dimensionless wave mplitude (m)",fontsize = 13)
axes[0].set_title("Far field wave amplitude for $H_{0}$ = 18.5 cm, $\u03BC$ = "+str(0.1)+" ($Ns/m^{2}$)" ,fontsize = 13)
axes[0].plot(df1["x"]-3.6,df1["y"]/0.185, color = 'c', linestyle = ':' , label = "b = 0.0")
#axes[0].plot(df2["x"]-3.7,df2["y"]/0.185, color = 'c', linestyle = '-.' , label = "b = 0.001")
#axes[0].plot(df3["x"]-3.7,df3["y"]/0.185, color = 'c', linestyle = '--' , label = "b = 0.005")
axes[0].plot(df4["x"]-3.6,df4["y"]/0.185, color = 'c', linestyle = '-' , label = "b = 0.01")
axes[0].plot(df5["x"]-3.6,df5["y"]/0.185, color = 'b', linestyle = ':' , label = "b = 0.02")
axes[0].plot(df6["x"]-3.6,df6["y"]/0.185, color = 'm', linestyle = '-.' , label = "b = 0.04")
axes[0].plot(df7["x"]-3.6,df7["y"]/0.185, color = 'm', linestyle = '-' , label = "b = 0.08")
axes[0].legend(fontsize = 15)
axes[0].set_xlim(0,2)


axes[1].set_xlabel("t/T (s)",fontsize = 13)
axes[1].set_ylabel("Dimensionless wave mplitude (m)",fontsize = 13)
axes[1].set_title("Far field wave amplitude for $H_{0}$ = 18.5 cm, $\u03BC$ = "+str(0.1)+" ($Ns/m^{2}$)" ,fontsize = 13)
axes[1].plot(df1a["x"]-3.6,df1a["y"]/0.185, color = 'c',  linestyle = ':' ,  label = "b = 0.0")
#axes[1].plot(df2a["x"]-3.7,df2a["y"]/0.185, color = 'c',  linestyle = '-.' , label = "b = 0.001")
#axes[1].plot(df3a["x"]-3.7,df3a["y"]/0.185, color = 'c',  linestyle = '--' , label = "b = 0.005")
axes[1].plot(df4a["x"]-3.6,df4a["y"]/0.185, color = 'c',  linestyle = '-' ,  label = "b = 0.01")
#axes[1].plot(df5a["x"]-3.6,df5a["y"]/0.185, color = 'b',  linestyle = ':' ,  label = "b = 0.02")
axes[1].plot(df6a["x"]-3.6,df6a["y"]/0.185, color = 'm',  linestyle = '-.' , label = "b = 0.04")
axes[1].plot(df7a["x"]-3.6,df7a["y"]/0.185, color = 'm',  linestyle = '-' ,  label = "b = 0.08")
axes[1].legend(fontsize = 15)
axes[1].set_xlim(0,2)


plt.savefig("amplitude.pdf")

# %%
Hi = 39.5

visc = 0.1
b = 0.001
fig, axes = plt.subplots(1,2,figsize = [16,8])

##Shear

def getdf(folder):
    df = pd.read_csv(folder+'/bwave_gauge_700cm.txt', names = ['x','y'], delim_whitespace=True)
    df = df.query('y > -0.02')
    return df



df1=getdf(str(Hi)+'_'+str(0.1)+'/b_'+str(0.0)+'_5')
df2=getdf(str(Hi)+'_'+str(0.1)+'/b_'+str(0.001)+'_5')
#df3=getdf(str(Hi)+'_'+str(0.1)+'/b_'+str(0.005)+'_5')
df4=getdf(str(Hi)+'_'+str(0.1)+'/b_'+str(0.01)+'_5')
df5=getdf(str(Hi)+'_'+str(0.1)+'/b_'+str(0.02)+'_5')
df6=getdf(str(Hi)+'_'+str(0.1)+'/b_'+str(0.04)+'_5')
df7=getdf(str(Hi)+'_'+str(0.1)+'/b_'+str(0.08)+'_5')

df1a=getdf(str(Hi)+'_'+str(0.01)+'/b_'+str(0.0)+'_5')
df2a=getdf(str(Hi)+'_'+str(0.01)+'/b_'+str(0.001)+'_5')
#df3a=getdf(str(Hi)+'_'+str(0.01)+'/b_'+str(0.005)+'_5')
#df4a=getdf(str(Hi)+'_'+str(0.01)+'/b_'+str(0.01)+'_5')
df5a=getdf(str(Hi)+'_'+str(0.01)+'/b_'+str(0.02)+'_5')
df6a=getdf(str(Hi)+'_'+str(0.01)+'/b_'+str(0.04)+'_5')
df7a=getdf(str(Hi)+'_'+str(0.01)+'/b_'+str(0.08)+'_5')





mycolors = ['g','c','b','m']
## c = shear, b = plunge, m = spill
#axes[0].set_xlim(0,1.5)
axes[0].set_xlabel("t/T (s)",fontsize = 13)
axes[0].set_ylabel("Dimensionless wave mplitude (m)",fontsize = 13)
axes[0].set_title("Far field wave amplitude for $H_{0}$ = 18.5 cm, $\u03BC$ = "+str(0.1)+" ($Ns/m^{2}$)" ,fontsize = 13)
axes[0].scatter(df1["x"],df1["y"]/0.395, color = 'c', linestyle = ':' , label = "b = 0.0")
axes[0].scatter(df2["x"],df2["y"]/0.395, color = 'c', linestyle = '-.' , label = "b = 0.001")
#axes[0].plot(df3["x"]-3.7,df3["y"]/0.395, color = 'c', linestyle = '--' , label = "b = 0.005")
axes[0].scatter(df4["x"],df4["y"]/0.395, color = 'c', linestyle = '-' , label = "b = 0.01")
axes[0].scatter(df5["x"],df5["y"]/0.395, color = 'b', linestyle = ':' , label = "b = 0.02")
axes[0].scatter(df6["x"],df6["y"]/0.395, color = 'm', linestyle = '-.' , label = "b = 0.04")
axes[0].scatter(df7["x"],df7["y"]/0.395, color = 'm', linestyle = '-' , label = "b = 0.08")
axes[0].legend(fontsize = 15)

#axes[1].set_xlim(0,1.5)
axes[1].set_xlabel("t/T (s)",fontsize = 13)
axes[1].set_ylabel("Dimensionless wave mplitude (m)",fontsize = 13)
axes[1].set_title("Far field wave amplitude for $H_{0}$ = 18.5 cm, $\u03BC$ = "+str(0.1)+" ($Ns/m^{2}$)" ,fontsize = 13)
axes[1].scatter(df1a["x"],df1a["y"]/0.395, color = 'c',  linestyle = ':' ,  label = "b = 0.0")
axes[1].scatter(df2a["x"],df2a["y"]/0.395, color = 'c',  linestyle = '-.' , label = "b = 0.001")
#axes[1].plot(df3a["x"]-3.7,df3a["y"]/0.395, color = 'c',  linestyle = '--' , label = "b = 0.005")
#axes[1].plot(df4a["x"]-3.7,df4a["y"]/0.395, color = 'c',  linestyle = '-' ,  label = "b = 0.01")
axes[1].scatter(df5a["x"],df5a["y"]/0.395, color = 'b',  linestyle = ':' ,  label = "b = 0.02")
axes[1].scatter(df6a["x"],df6a["y"]/0.395, color = 'm',  linestyle = '-.' , label = "b = 0.04")
axes[1].scatter(df7a["x"],df7a["y"]/0.395, color = 'm',  linestyle = '-' ,  label = "b = 0.08")
axes[1].legend(fontsize = 15)


plt.savefig("amplitude.pdf")

# %%
# Out:
# [0.001      0.00357895 0.00615789 0.00873684 0.01131579 0.01389474
#  0.01647368 0.01905263 0.02163158 0.02421053 0.02678947 0.02936842
#  0.03194737 0.03452632 0.03710526 0.03968421 0.04226316 0.04484211
#  0.04742105 0.05      ] [1.1700427342622908e+22, 3763177.1691513103, 11472.411483009366, 1069.1658966840143, 293.9014468479841, 130.481881041483, 74.69878624205137, 49.73415719984349, 36.48539051479241, 28.592043923269046, 23.483117523166605, 19.9655177601818, 17.425433946213857, 15.520837026089485, 14.048642084631563, 12.881870009628747, 11.937655291149689, 11.159938928061594, 10.509616087653788, 9.958678774529588]

# %%
print((0.01*math.log(3.5)+0.025)
# Out:
# 0.037527629684953684
